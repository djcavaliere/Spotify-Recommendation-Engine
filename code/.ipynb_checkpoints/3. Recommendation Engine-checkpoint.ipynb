# %% [markdown]
# ### Recommendation Engine
#
# Overview: The idea behind a song recommendation system is to identify songs that a user may enjoy based on their listening preferences. In order to accomplish this task I will pull in my listening history and compare various song features from my listening history with songs I not in my listening history to recommend songs that are most like the ones I listen to.
#
# Step 1: Combine my listening history with a random library of songs
# <br>Step 2: Preprocess the data so that each desired feature is considered
# <br>Step 3: Create a cosine similarity matrix
# <br>Step 4: Create a function to make recommendations given a selected song

# %% [markdown]
# ### Import Libraries & Data

# %%
import pandas as pd
import numpy as np
import pickle

from sklearn.metrics.pairwise import pairwise_distances, cosine_similarity, cosine_distances
from sklearn import preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
kaggle = pd.read_csv('../data/kaggle.csv')
# %store -r history

# %%
history.drop_duplicates(subset = 'trackID', inplace = True)
history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1426 entries, 0 to 3622
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   endTime            1426 non-null   object
#  1   artistName         1426 non-null   object
#  2   trackName          1426 non-null   object
#  3   msPlayed           1426 non-null   int64
#  4   count              1426 non-null   int64
#  5   artist_id          1426 non-null   object
#  6   genres             1426 non-null   object
#  7   artist_popularity  1426 non-null   float64
#  8   followers          1426 non-null   float64
#  9   trackID            1426 non-null   object
#  10  danceability       1426 non-null   float64
#  11  energy             1426 non-null   float64
#  12  key                1426 non-null   float64
#  13  loudness           1426 non-null   float64
#  14  mode               1426 non-null   float64
#  15  speechiness        1426 non-null   float64
#  16  acousticness       1426 non-null   float64
#  17  instrumentalness   1426 non-null   float64
#  18  liveness           1426 non-null   float64
#  19  valence            1426 non-null   float64
#  20  tempo              1426 non-null   float64
#  21  duration_ms        1426 non-null   float64
#  22  time_signature     1426 non-null   float64
# dtypes: float64(15), int64(2), object(6)
# memory usage: 267.4+ KB

# %%
history.head(1)
# Out:
#             endTime     artistName                               trackName  \
# 0  2021-10-26 23:02  Daniel Caesar  Transform (feat. Charlotte Day Wilson)
#
#    msPlayed  count               artist_id  \
# 0    277984      1  20wkVLutqVOYrc0kxFs7rA
#
#                                         genres  artist_popularity  followers  \
# 0  ['canadian contemporary r&b', 'pop', 'r&b']               76.0  3551511.0
#
#                   trackID  ...  loudness  mode  speechiness  acousticness  \
# 0  1jQfgl9WRle7D8a3GXLwaD  ...   -10.656   1.0        0.031         0.511
#
#    instrumentalness  liveness  valence   tempo  duration_ms  time_signature
# 0          0.000019     0.256    0.348  68.963     280587.0             4.0
#
# [1 rows x 23 columns]

# %%
kaggle.dropna(inplace = True)
kaggle.drop_duplicates(subset = 'id', inplace = True)
kaggle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162853 entries, 0 to 170652
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        162853 non-null  int64
#  1   valence           162853 non-null  float64
#  2   year              162853 non-null  int64
#  3   acousticness      162853 non-null  float64
#  4   artists           162853 non-null  object
#  5   danceability      162853 non-null  float64
#  6   duration_ms       162853 non-null  int64
#  7   energy            162853 non-null  float64
#  8   explicit          162853 non-null  int64
#  9   id                162853 non-null  object
#  10  instrumentalness  162853 non-null  float64
#  11  key               162853 non-null  int64
#  12  liveness          162853 non-null  float64
#  13  loudness          162853 non-null  float64
#  14  mode              162853 non-null  int64
#  15  name              162853 non-null  object
#  16  popularity        162853 non-null  int64
#  17  release_date      162853 non-null  object
#  18  speechiness       162853 non-null  float64
#  19  tempo             162853 non-null  float64
#  20  artist_id         162853 non-null  object
#  21  artistName        162853 non-null  object
#  22  genre             162853 non-null  object
#  23  followers         162853 non-null  float64
# dtypes: float64(10), int64(7), object(7)
# memory usage: 31.1+ MB

# %%
historytemp = history.drop(columns = ['endTime', 'msPlayed', 'count', 'artist_id', 'duration_ms', 'time_signature', 'trackID'])
historytemp.head()
# Out:
#       artistName                               trackName  \
# 0  Daniel Caesar  Transform (feat. Charlotte Day Wilson)
# 1    Nia Sultana                           Coconut Water
# 2    Nia Sultana                               Positions
# 3         Wizkid                    Essence (feat. Tems)
# 4           Nija                                 Finesse
#
#                                               genres  artist_popularity  \
# 0        ['canadian contemporary r&b', 'pop', 'r&b']               76.0
# 1      ['alternative r&b', 'chill r&b', 'indie r&b']               42.0
# 2      ['alternative r&b', 'chill r&b', 'indie r&b']               42.0
# 3  ['afro dancehall', 'afropop', 'azonto', 'niger...               76.0
# 4  ['alternative r&b', 'indie r&b', 'pop r&b', 'r...               48.0
#
#    followers  danceability  energy   key  loudness  mode  speechiness  \
# 0  3551511.0         0.498   0.292   5.0   -10.656   1.0       0.0310
# 1    18048.0         0.724   0.432  11.0    -9.945   1.0       0.2030
# 2    18048.0         0.639   0.535   1.0    -7.714   1.0       0.0596
# 3  2822455.0         0.849   0.707   0.0    -6.002   1.0       0.1130
# 4    30018.0         0.795   0.486   5.0    -8.364   1.0       0.0475
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0        0.5110          0.000019    0.2560    0.348   68.963
# 1        0.0876          0.000032    0.0828    0.696   84.992
# 2        0.4890          0.001260    0.1090    0.321   84.975
# 3        0.0266          0.000009    0.6180    0.602  104.027
# 4        0.1340          0.000026    0.2600    0.351  132.045

# %%
library = kaggle.drop(columns = ['Unnamed: 0','year', 'duration_ms', 'explicit', 'release_date', 'artistName', 'artist_id', 'id'])
library.head()
# Out:
#    valence  acousticness                                            artists  \
# 0   0.0594         0.982  ['Sergei Rachmaninoff', 'James Levine', 'Berli...
# 1   0.9630         0.732                                     ['Dennis Day']
# 2   0.0394         0.961  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...
# 3   0.1650         0.967                                   ['Frank Parker']
# 4   0.2530         0.957                                     ['Phil Regan']
#
#    danceability  energy  instrumentalness  key  liveness  loudness  mode  \
# 0         0.279   0.211          0.878000   10     0.665   -20.096     1
# 1         0.819   0.341          0.000000    7     0.160   -12.441     1
# 2         0.328   0.166          0.913000    3     0.101   -14.850     1
# 3         0.275   0.309          0.000028    5     0.381    -9.316     1
# 4         0.418   0.193          0.000002    3     0.229   -10.096     1
#
#                                                 name  popularity  speechiness  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4       0.0366
# 1                            Clancy Lowered the Boom           5       0.4150
# 2                                          Gati Bali           5       0.0339
# 3                                          Danny Boy           3       0.0354
# 4                        When Irish Eyes Are Smiling           2       0.0380
#
#      tempo                                              genre  followers
# 0   80.954  ['classical', 'post-romantic era', 'russian ro...   560524.0
# 1   60.936                                                 []      551.0
# 2  110.339                               ['javanese gamelan']      438.0
# 3  100.109                                                 []        0.0
# 4  101.665                                                 []       26.0

# %%
print(library.shape, historytemp.shape)
# Out:
# (162853, 16) (1426, 16)

# %%
library = library[['name', 'artists', 'genre', 'popularity', 'followers', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
library.rename(columns = {'name':'trackName','artists':'artistName', 'popularity': 'artist_popularity', 'genre':'genres'}, inplace = True)
library.head()
# Out:
#                                            trackName  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 1                            Clancy Lowered the Boom
# 2                                          Gati Bali
# 3                                          Danny Boy
# 4                        When Irish Eyes Are Smiling
#
#                                           artistName  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...
# 1                                     ['Dennis Day']
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...
# 3                                   ['Frank Parker']
# 4                                     ['Phil Regan']
#
#                                               genres  artist_popularity  \
# 0  ['classical', 'post-romantic era', 'russian ro...                  4
# 1                                                 []                  5
# 2                               ['javanese gamelan']                  5
# 3                                                 []                  3
# 4                                                 []                  2
#
#    followers  danceability  energy  key  loudness  mode  speechiness  \
# 0   560524.0         0.279   0.211   10   -20.096     1       0.0366
# 1      551.0         0.819   0.341    7   -12.441     1       0.4150
# 2      438.0         0.328   0.166    3   -14.850     1       0.0339
# 3        0.0         0.275   0.309    5    -9.316     1       0.0354
# 4       26.0         0.418   0.193    3   -10.096     1       0.0380
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.982          0.878000     0.665   0.0594   80.954
# 1         0.732          0.000000     0.160   0.9630   60.936
# 2         0.961          0.913000     0.101   0.0394  110.339
# 3         0.967          0.000028     0.381   0.1650  100.109
# 4         0.957          0.000002     0.229   0.2530  101.665

# %%
combined = pd.concat([library, historytemp], axis=0)
combined.shape
# Out:
# (164279, 16)

# %%
combined['Song'] = combined['trackName'] + '-' + combined['artistName'] 
combined.drop(columns = ['trackName', 'artistName'], inplace = True)

# %%
combined.head(1)
# Out:
#                                               genres  artist_popularity  \
# 0  ['classical', 'post-romantic era', 'russian ro...                4.0
#
#    followers  danceability  energy   key  loudness  mode  speechiness  \
# 0   560524.0         0.279   0.211  10.0   -20.096   1.0       0.0366
#
#    acousticness  instrumentalness  liveness  valence   tempo  \
# 0         0.982             0.878     0.665   0.0594  80.954
#
#                                                 Song
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...

# %% [markdown]
# #### Feature Engineering
#
# Features
# <br> danceability, energy, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, genre, popularity, followers
#
# 1) Normalize values over 1
# 2) Get Dummies or TFDIF on the genre
# 3) Turn into single vector
# 4) Calculate Cosine Similarity
# 5) Generate Recommendations

# %% [markdown]
# ### Recommendation System -- No Genres --

# %%
#Create a datframe without genres
temp = combined.drop(columns = ['genres', 'Song'])
temp.index = combined['Song']
temp.head()
# Out:
#                                                     artist_popularity  \
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                4.0
# Clancy Lowered the Boom-['Dennis Day']                            5.0
# Gati Bali-['KHP Kridhamardawa Karaton Ngayogyak...                5.0
# Danny Boy-['Frank Parker']                                        3.0
# When Irish Eyes Are Smiling-['Phil Regan']                        2.0
#
#                                                     followers  danceability  \
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...   560524.0         0.279
# Clancy Lowered the Boom-['Dennis Day']                  551.0         0.819
# Gati Bali-['KHP Kridhamardawa Karaton Ngayogyak...      438.0         0.328
# Danny Boy-['Frank Parker']                                0.0         0.275
# When Irish Eyes Are Smiling-['Phil Regan']               26.0         0.418
#
#                                                     energy   key  loudness  \
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...   0.211  10.0   -20.096
# Clancy Lowered the Boom-['Dennis Day']               0.341   7.0   -12.441
# Gati Bali-['KHP Kridhamardawa Karaton Ngayogyak...   0.166   3.0   -14.850
# Danny Boy-['Frank Parker']                           0.309   5.0    -9.316
# When Irish Eyes Are Smiling-['Phil Regan']           0.193   3.0   -10.096
#
#                                                     mode  speechiness  \
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...   1.0       0.0366
# Clancy Lowered the Boom-['Dennis Day']               1.0       0.4150
# Gati Bali-['KHP Kridhamardawa Karaton Ngayogyak...   1.0       0.0339
# Danny Boy-['Frank Parker']                           1.0       0.0354
# When Irish Eyes Are Smiling-['Phil Regan']           1.0       0.0380
#
#                                                     acousticness  \
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...         0.982
# Clancy Lowered the Boom-['Dennis Day']                     0.732
# Gati Bali-['KHP Kridhamardawa Karaton Ngayogyak...         0.961
# Danny Boy-['Frank Parker']                                 0.967
# When Irish Eyes Are Smiling-['Phil Regan']                 0.957
#
#                                                     instrumentalness  \
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...          0.878000
# Clancy Lowered the Boom-['Dennis Day']                      0.000000
# Gati Bali-['KHP Kridhamardawa Karaton Ngayogyak...          0.913000
# Danny Boy-['Frank Parker']                                  0.000028
# When Irish Eyes Are Smiling-['Phil Regan']                  0.000002
#
#                                                     liveness  valence    tempo
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...     0.665   0.0594   80.954
# Clancy Lowered the Boom-['Dennis Day']                 0.160   0.9630   60.936
# Gati Bali-['KHP Kridhamardawa Karaton Ngayogyak...     0.101   0.0394  110.339
# Danny Boy-['Frank Parker']                             0.381   0.1650  100.109
# When Irish Eyes Are Smiling-['Phil Regan']             0.229   0.2530  101.665

# %% [markdown]
# ### Get Recommendations

# %%
temp.dropna(inplace = True)
temp.shape
# Out:
# (164279, 13)

# %%
temp.index[-1]
# Out:
# '2 Be Loved (Am I Ready)-Lizzo'

# %%
#calculate similarity scores
similarity = cosine_similarity(temp, temp.iloc[[-1]])

# sim = pd.DataFrame(similarity, index = temp.index, columns = temp.iloc[[0]].index)
sim = pd.DataFrame(similarity, index = temp.index, columns = [temp.index[-1]])

# %%
sim.sort_values(by = temp.index[-1], ascending = False).head(10)
# Out:
#                                          2 Be Loved (Am I Ready)-Lizzo
# Song
# 2 Be Loved (Am I Ready)-Lizzo                                      1.0
# Sex on Fire-['Kings of Leon']                                      1.0
# Truth Hurts-['Lizzo']                                              1.0
# Unforgettable-['Thomas Rhett']                                     1.0
# Truth Hurts-Lizzo                                                  1.0
# Crash and Burn-['Thomas Rhett']                                    1.0
# Solamente tú-['Pablo Alborán']                                     1.0
# We Didn't Start the Fire-['Billy Joel']                            1.0
# He Could Be the One-['Hannah Montana']                             1.0
# Pistearé-['Banda Los Recoditos']                                   1.0

# %%
#Recommendation Function- Update this to only return the Song not the similarity score
def get_recommendations(library, user_input):
    #calculate similarity
    similarity = cosine_similarity(library, user_input)
    
    #create a similarity DataFrame
    sim = pd.DataFrame(similarity, index = library.index, columns = [user_input.index[0]])
    
    #filter to top 5 
    recs = sim.sort_values(by = test.index[0], ascending = False)[1:6]
    
    return recs

# %%
get_recommendations(temp, test)
# Out:
#                                                Have You Ever Loved A Woman
# Song
# What Is Love? - Extended Mix-['Howard Jones']                          1.0
# Ice Ice Baby-['Vanilla Ice']                                           1.0
# Honey White-['Morphine']                                               1.0
# September In The Rain-['Dinah Washington']                             1.0
# Suburban Home-['Descendents']                                          1.0

# %%
# with open('../models/get_recommendation.pkl', 'wb') as f:
#     pickle.dump(get_recommendations, f)

# %%
# with open('../models/library.pkl', 'wb') as f:
#     pickle.dump(temp, f)

# %%
# %store -r test

# %% [markdown]
# #### Recommendations are not great some things to experiment:
# <br>Add Genre
# <br>Normalize Features- Will have to do this on the input song as well* likely manual w/function
# <br>Check recommendations against library list and only surface recommendations in the same genre

# %% [markdown]
# #### Normalizing Features

# %%
#Step 1 Normalize Features over 1
normalized = combined
normalized['artist_popularity'] = pd.DataFrame(preprocessing.normalize([normalized['artist_popularity']]).T)
normalized['loudness'] = pd.DataFrame(preprocessing.normalize([normalized['loudness']]).T)
normalized['followers'] = pd.DataFrame(preprocessing.normalize([normalized['followers']]).T)
normalized['tempo'] = pd.DataFrame(preprocessing.normalize([normalized['tempo']]).T)
normalized['key'] = pd.DataFrame(preprocessing.normalize([normalized['key']]).T)

# %%
normalized.index = normalized['Song']
normalized.drop(columns = ['Song', 'genres'], inplace = True)
normalized.head(1)
# Out:
#                                                     artist_popularity  \
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...           0.000258
#
#                                                     followers  danceability  \
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...   0.000175         0.279
#
#                                                     energy       key  \
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...   0.211  0.003934
#
#                                                     loudness  mode  \
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F... -0.003876   1.0
#
#                                                     speechiness  acousticness  \
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...       0.0366         0.982
#
#                                                     instrumentalness  \
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...             0.878
#
#                                                     liveness  valence  \
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...     0.665   0.0594
#
#                                                        tempo
# Song
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...  0.001652

# %%
normalized.shape
# Out:
# (164279, 13)

# %%
combined['followers'].max()
# Out:
# 104542644.0

# %%
combined['followers'].min()
# Out:
# 0.0

# %%
combined.head(1)
# Out:
#                                               genres  artist_popularity  \
# 0  ['classical', 'post-romantic era', 'russian ro...                4.0
#
#    followers  danceability  energy   key  loudness  mode  speechiness  \
# 0   560524.0         0.279   0.211  10.0   -20.096   1.0       0.0366
#
#    acousticness  instrumentalness  liveness  valence   tempo  \
# 0         0.982             0.878     0.665   0.0594  80.954
#
#                                                 Song
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...

# %% [markdown]
# #### Recommendation with Genre
# Not seeing much difference with Genre included. I am trying to first calculate the scores then only surface recommendations within the same genre. The problem is the genres column is a long list so its likely an exact match on genres would only surface songs from the same artist. Is there a way I can write a function to identify songs with at least 1 matching genre in the genres list.

# %%
#Step 2 TFDIF Genre Category
combined['genres'] = [''.join(x) for x in combined['genres']]

vectorizer = TfidfVectorizer(max_features = 200)
vectors = vectorizer.fit_transform(combined['genres'])
vocab = vectorizer.vocabulary_

genre_tfdf = pd.DataFrame(vectors.toarray(), columns = [vectorizer.get_feature_names_out()])

genre_tfdf.reset_index(drop = True, inplace=True)
genre_tfdf.iloc[0]
# Out:
# acoustic       0.0
# adult          0.0
# age            0.0
# album          0.0
# alternative    0.0
#               ...
# wave           0.0
# west           0.0
# worship        0.0
# yacht          0.0
# zolo           0.0
# Name: 0, Length: 200, dtype: float64

# %%
#Step 3
combined.reset_index(inplace = True, drop = True)
df = pd.concat([combined, genre_tfdf], axis = 1)

# %%
df.index= df['Song']

# %%
df.drop(columns = ['genres', 'Song'], inplace = True)

# %%
similarity = cosine_similarity(df, df.iloc[[-1]])

# %%
sim = pd.DataFrame(similarity, index = df.index, columns = [df.index[-1]])

# %%
sim.sort_values(by = df.index[-1], ascending = False).head(10)
# Out:
#                                          2 Be Loved (Am I Ready)-Lizzo
# Song
# 2 Be Loved (Am I Ready)-Lizzo                                      1.0
# Sex on Fire-['Kings of Leon']                                      1.0
# Truth Hurts-['Lizzo']                                              1.0
# Truth Hurts-Lizzo                                                  1.0
# Unforgettable-['Thomas Rhett']                                     1.0
# Crash and Burn-['Thomas Rhett']                                    1.0
# Solamente tú-['Pablo Alborán']                                     1.0
# We Didn't Start the Fire-['Billy Joel']                            1.0
# He Could Be the One-['Hannah Montana']                             1.0
# Pistearé-['Banda Los Recoditos']                                   1.0

# %%
rec_genre = combined[['genres']]

# %%
rec_genre.index = df.index

# %%
rec_genre['score'] = sim['2 Be Loved (Am I Ready)-Lizzo']
# Out:
# C:\Users\dylan\AppData\Local\Temp\ipykernel_13308\2627595150.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_genre['score'] = sim['2 Be Loved (Am I Ready)-Lizzo']

# %%
#The problem here is that if I do an exact match on genres I will only pull songs from same artist
rec_genre[rec_genre['genres'] == rec_genre.loc['2 Be Loved (Am I Ready)-Lizzo']['genres']]
# Out:
#                                                                                           genres  \
# Song
# Truth Hurts-['Lizzo']                          ['escape room', 'minnesota hip hop', 'pop', 't...
# Good as Hell-['Lizzo']                         ['escape room', 'minnesota hip hop', 'pop', 't...
# Juice-['Lizzo']                                ['escape room', 'minnesota hip hop', 'pop', 't...
# Good as Hell-['Lizzo']                         ['escape room', 'minnesota hip hop', 'pop', 't...
# When I Rule the World-['LIZ']                  ['escape room', 'minnesota hip hop', 'pop', 't...
# Boys-['Lizzo']                                 ['escape room', 'minnesota hip hop', 'pop', 't...
# Cuz I Love You-['Lizzo']                       ['escape room', 'minnesota hip hop', 'pop', 't...
# Soulmate-['Lizzo']                             ['escape room', 'minnesota hip hop', 'pop', 't...
# Like a Girl-['Lizzo']                          ['escape room', 'minnesota hip hop', 'pop', 't...
# Scuse Me-['Lizzo']                             ['escape room', 'minnesota hip hop', 'pop', 't...
# Fitness-['Lizzo']                              ['escape room', 'minnesota hip hop', 'pop', 't...
# Worship-['Lizzo']                              ['escape room', 'minnesota hip hop', 'pop', 't...
# Rumors (feat. Cardi B)-Lizzo                   ['escape room', 'minnesota hip hop', 'pop', 't...
# Truth Hurts-Lizzo                              ['escape room', 'minnesota hip hop', 'pop', 't...
# Juice-Lizzo                                    ['escape room', 'minnesota hip hop', 'pop', 't...
# Fitness-Lizzo                                  ['escape room', 'minnesota hip hop', 'pop', 't...
# Phone-Lizzo                                    ['escape room', 'minnesota hip hop', 'pop', 't...
# Good as Hell-Lizzo                             ['escape room', 'minnesota hip hop', 'pop', 't...
# Cuz I Love You-Lizzo                           ['escape room', 'minnesota hip hop', 'pop', 't...
# Scuse Me-Lizzo                                 ['escape room', 'minnesota hip hop', 'pop', 't...
# Stayin' Alive (from Happy Death Day 2U)-Lizzo  ['escape room', 'minnesota hip hop', 'pop', 't...
# Boys-Lizzo                                     ['escape room', 'minnesota hip hop', 'pop', 't...
# Like a Girl-Lizzo                              ['escape room', 'minnesota hip hop', 'pop', 't...
# Worship-Lizzo                                  ['escape room', 'minnesota hip hop', 'pop', 't...
# Water Me-Lizzo                                 ['escape room', 'minnesota hip hop', 'pop', 't...
# Soulmate-Lizzo                                 ['escape room', 'minnesota hip hop', 'pop', 't...
# Coconut Oil-Lizzo                              ['escape room', 'minnesota hip hop', 'pop', 't...
# Let 'em Say-Lizzo                              ['escape room', 'minnesota hip hop', 'pop', 't...
# Better in Color-Lizzo                          ['escape room', 'minnesota hip hop', 'pop', 't...
# Tempo (feat. Missy Elliott)-Lizzo              ['escape room', 'minnesota hip hop', 'pop', 't...
# Lizzie Borden-Lizzo                            ['escape room', 'minnesota hip hop', 'pop', 't...
# Deep-Lizzo                                     ['escape room', 'minnesota hip hop', 'pop', 't...
# Ride-Lizzo                                     ['escape room', 'minnesota hip hop', 'pop', 't...
# Exactly How I Feel (feat. Gucci Mane)-Lizzo    ['escape room', 'minnesota hip hop', 'pop', 't...
# Paris-Lizzo                                    ['escape room', 'minnesota hip hop', 'pop', 't...
# About Damn Time-Lizzo                          ['escape room', 'minnesota hip hop', 'pop', 't...
# 2 Be Loved (Am I Ready)-Lizzo                  ['escape room', 'minnesota hip hop', 'pop', 't...
#
#                                                score
# Song
# Truth Hurts-['Lizzo']                            1.0
# Good as Hell-['Lizzo']                           1.0
# Juice-['Lizzo']                                  1.0
# Good as Hell-['Lizzo']                           1.0
# When I Rule the World-['LIZ']                    1.0
# Boys-['Lizzo']                                   1.0
# Cuz I Love You-['Lizzo']                         1.0
# Soulmate-['Lizzo']                               1.0
# Like a Girl-['Lizzo']                            1.0
# Scuse Me-['Lizzo']                               1.0
# Fitness-['Lizzo']                                1.0
# Worship-['Lizzo']                                1.0
# Rumors (feat. Cardi B)-Lizzo                     1.0
# Truth Hurts-Lizzo                                1.0
# Juice-Lizzo                                      1.0
# Fitness-Lizzo                                    1.0
# Phone-Lizzo                                      1.0
# Good as Hell-Lizzo                               1.0
# Cuz I Love You-Lizzo                             1.0
# Scuse Me-Lizzo                                   1.0
# Stayin' Alive (from Happy Death Day 2U)-Lizzo    1.0
# Boys-Lizzo                                       1.0
# Like a Girl-Lizzo                                1.0
# Worship-Lizzo                                    1.0
# Water Me-Lizzo                                   1.0
# Soulmate-Lizzo                                   1.0
# Coconut Oil-Lizzo                                1.0
# Let 'em Say-Lizzo                                1.0
# Better in Color-Lizzo                            1.0
# Tempo (feat. Missy Elliott)-Lizzo                1.0
# Lizzie Borden-Lizzo                              1.0
# Deep-Lizzo                                       1.0
# Ride-Lizzo                                       1.0
# Exactly How I Feel (feat. Gucci Mane)-Lizzo      1.0
# Paris-Lizzo                                      1.0
# About Damn Time-Lizzo                            1.0
# 2 Be Loved (Am I Ready)-Lizzo                    1.0

# %%
rec_genre.sort_values(by = 'score', ascending = False)
# Out:
#                                                                                                genres  \
# Song
# 2 Be Loved (Am I Ready)-Lizzo                       ['escape room', 'minnesota hip hop', 'pop', 't...
# Sex on Fire-['Kings of Leon']                                                 ['modern rock', 'rock']
# Truth Hurts-['Lizzo']                               ['escape room', 'minnesota hip hop', 'pop', 't...
# Truth Hurts-Lizzo                                   ['escape room', 'minnesota hip hop', 'pop', 't...
# Unforgettable-['Thomas Rhett']                      ['contemporary country', 'country', 'country r...
# ...                                                                                               ...
# Regard du Fils sur le Fils-['Anca Elena']                                                          []
# Regard du Père-['Anca Elena']                                                                      []
# Chapter 2.16 - Zamek kaniowski-['Seweryn Goszcz...                                                 []
# Chapter 3.17 - Dziewczynka z Luna Parku: Część ...                                                 []
# Chapter 1.26 & Chapter 2.1 - Dziewczynka z Luna...                                                 []
#
#                                                        score
# Song
# 2 Be Loved (Am I Ready)-Lizzo                       1.000000
# Sex on Fire-['Kings of Leon']                       1.000000
# Truth Hurts-['Lizzo']                               1.000000
# Truth Hurts-Lizzo                                   1.000000
# Unforgettable-['Thomas Rhett']                      1.000000
# ...                                                      ...
# Regard du Fils sur le Fils-['Anca Elena']           0.000028
# Regard du Père-['Anca Elena']                       0.000028
# Chapter 2.16 - Zamek kaniowski-['Seweryn Goszcz...  0.000028
# Chapter 3.17 - Dziewczynka z Luna Parku: Część ...  0.000027
# Chapter 1.26 & Chapter 2.1 - Dziewczynka z Luna...  0.000026
#
# [164279 rows x 2 columns]
