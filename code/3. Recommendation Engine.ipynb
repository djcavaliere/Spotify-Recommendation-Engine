# %% [markdown]
# ### Recommendation Engine
#
# Overview: The idea behind a song recommendation system is to identify songs that a user may enjoy based on their listening preferences. In order to accomplish this task I will pull in my listening history and compare various song features from my listening history with songs I not in my listening history to recommend songs that are most like the ones I listen to.
#
# Step 1: Combine my listening history with a random library of songs
# <br>Step 2: Preprocess the data so that each desired feature is considered
# <br>Step 3: Create a cosine similarity matrix
# <br>Step 4: Create a function to make recommendations given a selected song

# %% [markdown]
# ### Import Libraries & Data

# %%
from sklearn.metrics.pairwise import pairwise_distances, cosine_similarity, cosine_distances
from sklearn import preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np

# %%
# %store -r history
# %store -r kaggle

# %%
history.drop_duplicates(subset = 'trackID', inplace = True)
history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1426 entries, 0 to 3796
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   endTime            1426 non-null   object
#  1   artistName         1426 non-null   object
#  2   trackName          1426 non-null   object
#  3   msPlayed           1426 non-null   int64
#  4   count              1426 non-null   int64
#  5   artist_id          1426 non-null   object
#  6   genres             1426 non-null   object
#  7   artist_popularity  1426 non-null   float64
#  8   followers          1426 non-null   float64
#  9   trackID            1426 non-null   object
#  10  danceability       1426 non-null   float64
#  11  energy             1426 non-null   float64
#  12  key                1426 non-null   float64
#  13  loudness           1426 non-null   float64
#  14  mode               1426 non-null   float64
#  15  speechiness        1426 non-null   float64
#  16  acousticness       1426 non-null   float64
#  17  instrumentalness   1426 non-null   float64
#  18  liveness           1426 non-null   float64
#  19  valence            1426 non-null   float64
#  20  tempo              1426 non-null   float64
#  21  duration_ms        1426 non-null   float64
#  22  time_signature     1426 non-null   float64
# dtypes: float64(15), int64(2), object(6)
# memory usage: 267.4+ KB

# %%
history.head(1)
# Out:
#             endTime     artistName                               trackName  \
# 0  2021-10-26 23:02  Daniel Caesar  Transform (feat. Charlotte Day Wilson)
#
#    msPlayed  count               artist_id  \
# 0    277984      1  20wkVLutqVOYrc0kxFs7rA
#
#                                   genres  artist_popularity  followers  \
# 0  [canadian contemporary r&b, pop, r&b]               76.0  3551511.0
#
#                   trackID  ...  loudness  mode  speechiness  acousticness  \
# 0  1jQfgl9WRle7D8a3GXLwaD  ...   -10.656   1.0        0.031         0.511
#
#    instrumentalness  liveness  valence   tempo  duration_ms  time_signature
# 0          0.000019     0.256    0.348  68.963     280587.0             4.0
#
# [1 rows x 23 columns]

# %%
kaggle.dropna(inplace = True)
kaggle.drop_duplicates(subset = 'id', inplace = True)
kaggle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162853 entries, 0 to 170652
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           162853 non-null  float64
#  1   year              162853 non-null  int64
#  2   acousticness      162853 non-null  float64
#  3   artists           162853 non-null  object
#  4   danceability      162853 non-null  float64
#  5   duration_ms       162853 non-null  int64
#  6   energy            162853 non-null  float64
#  7   explicit          162853 non-null  int64
#  8   id                162853 non-null  object
#  9   instrumentalness  162853 non-null  float64
#  10  key               162853 non-null  int64
#  11  liveness          162853 non-null  float64
#  12  loudness          162853 non-null  float64
#  13  mode              162853 non-null  int64
#  14  name              162853 non-null  object
#  15  popularity        162853 non-null  int64
#  16  release_date      162853 non-null  object
#  17  speechiness       162853 non-null  float64
#  18  tempo             162853 non-null  float64
#  19  artist_id         162853 non-null  object
#  20  artistName        162853 non-null  object
#  21  genre             162853 non-null  object
#  22  followers         162853 non-null  float64
# dtypes: float64(10), int64(6), object(7)
# memory usage: 29.8+ MB

# %%
historytemp = history.drop(columns = ['endTime', 'artistName', 'msPlayed', 'count', 'artist_id', 'duration_ms', 'time_signature', 'trackID'])
historytemp.head()
# Out:
#                                 trackName  \
# 0  Transform (feat. Charlotte Day Wilson)
# 1                           Coconut Water
# 2                               Positions
# 3                    Essence (feat. Tems)
# 4                                 Finesse
#
#                                               genres  artist_popularity  \
# 0              [canadian contemporary r&b, pop, r&b]               76.0
# 1            [alternative r&b, chill r&b, indie r&b]               42.0
# 2            [alternative r&b, chill r&b, indie r&b]               42.0
# 3  [afro dancehall, afropop, azonto, nigerian hip...               76.0
# 4         [alternative r&b, indie r&b, pop r&b, r&b]               48.0
#
#    followers  danceability  energy   key  loudness  mode  speechiness  \
# 0  3551511.0         0.498   0.292   5.0   -10.656   1.0       0.0310
# 1    18048.0         0.724   0.432  11.0    -9.945   1.0       0.2030
# 2    18048.0         0.639   0.535   1.0    -7.714   1.0       0.0596
# 3  2822455.0         0.849   0.707   0.0    -6.002   1.0       0.1130
# 4    30018.0         0.795   0.486   5.0    -8.364   1.0       0.0475
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0        0.5110          0.000019    0.2560    0.348   68.963
# 1        0.0876          0.000032    0.0828    0.696   84.992
# 2        0.4890          0.001260    0.1090    0.321   84.975
# 3        0.0266          0.000009    0.6180    0.602  104.027
# 4        0.1340          0.000026    0.2600    0.351  132.045

# %%
library = kaggle.drop(columns = ['year', 'artists', 'duration_ms', 'explicit', 'release_date', 'artistName', 'artist_id', 'id'])
library.head()
# Out:
#    valence  acousticness  danceability  energy  instrumentalness  key  \
# 0   0.0594         0.982         0.279   0.211          0.878000   10
# 1   0.9630         0.732         0.819   0.341          0.000000    7
# 2   0.0394         0.961         0.328   0.166          0.913000    3
# 3   0.1650         0.967         0.275   0.309          0.000028    5
# 4   0.2530         0.957         0.418   0.193          0.000002    3
#
#    liveness  loudness  mode  \
# 0     0.665   -20.096     1
# 1     0.160   -12.441     1
# 2     0.101   -14.850     1
# 3     0.381    -9.316     1
# 4     0.229   -10.096     1
#
#                                                 name  popularity  speechiness  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4       0.0366
# 1                            Clancy Lowered the Boom           5       0.4150
# 2                                          Gati Bali           5       0.0339
# 3                                          Danny Boy           3       0.0354
# 4                        When Irish Eyes Are Smiling           2       0.0380
#
#      tempo                                              genre  followers
# 0   80.954  [classical, post-romantic era, russian romanti...   560524.0
# 1   60.936                                                 []      551.0
# 2  110.339                                 [javanese gamelan]      438.0
# 3  100.109                                                 []        0.0
# 4  101.665                                                 []       26.0

# %%
print(library.shape, historytemp.shape)
# Out:
# (162853, 15) (1426, 15)

# %%
library = library[['name', 'genre', 'popularity', 'followers', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
library.rename(columns = {'name':'trackName', 'popularity': 'artist_popularity', 'genre':'genres'}, inplace = True)
library.head()
# Out:
#                                            trackName  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 1                            Clancy Lowered the Boom
# 2                                          Gati Bali
# 3                                          Danny Boy
# 4                        When Irish Eyes Are Smiling
#
#                                               genres  artist_popularity  \
# 0  [classical, post-romantic era, russian romanti...                  4
# 1                                                 []                  5
# 2                                 [javanese gamelan]                  5
# 3                                                 []                  3
# 4                                                 []                  2
#
#    followers  danceability  energy  key  loudness  mode  speechiness  \
# 0   560524.0         0.279   0.211   10   -20.096     1       0.0366
# 1      551.0         0.819   0.341    7   -12.441     1       0.4150
# 2      438.0         0.328   0.166    3   -14.850     1       0.0339
# 3        0.0         0.275   0.309    5    -9.316     1       0.0354
# 4       26.0         0.418   0.193    3   -10.096     1       0.0380
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.982          0.878000     0.665   0.0594   80.954
# 1         0.732          0.000000     0.160   0.9630   60.936
# 2         0.961          0.913000     0.101   0.0394  110.339
# 3         0.967          0.000028     0.381   0.1650  100.109
# 4         0.957          0.000002     0.229   0.2530  101.665

# %%
combined = pd.concat([library, historytemp], axis=0)
combined.shape
# Out:
# (164279, 15)

# %%
combined.isnull().sum()
# Out:
# trackName            0
# genres               0
# artist_popularity    0
# followers            0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# dtype: int64

# %% [markdown]
# #### Feature Engineering
#
# Features
# <br> danceability, energy, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, genre, popularity, followers
#
# 1) Normalize values over 1
# 2) Get Dummies or TFDIF on the genre
# 3) Turn into single vector
# 4) Calculate Cosine Similarity
# 5) Generate Recommendations

# %%
features = ['danceability', 'energy', 'loudness', 'mode', 'speechiness', 'acousticness', 
            'instrumentalness', 'liveness', 'valence', 'popularity', 'genre', 'followers', 'tempo', 'key']

# %%
#Step 1 Normalize Features over 1
combined['artist_popularity'] = pd.DataFrame(preprocessing.normalize([combined['artist_popularity']]).T)
combined['loudness'] = pd.DataFrame(preprocessing.normalize([combined['loudness']]).T)
combined['followers'] = pd.DataFrame(preprocessing.normalize([combined['followers']]).T)
combined['tempo'] = pd.DataFrame(preprocessing.normalize([combined['tempo']]).T)
combined['key'] = pd.DataFrame(preprocessing.normalize([combined['key']]).T)

# %%
#Step 2 TFDIF Genre Category
combined['genres'] = [''.join(x) for x in combined['genres']]

vectorizer = TfidfVectorizer(max_features = 5000)
vectors = vectorizer.fit_transform(combined['genres'])
vocab = vectorizer.vocabulary_

genre_tfdf = pd.DataFrame(vectors.toarray(), columns = [vectorizer.get_feature_names_out()])

genre_tfdf.reset_index(drop = True, inplace=True)
genre_tfdf.iloc[0]
# Out:
# 21st                  0.0
# 6indie                0.0
# abstract              0.0
# accordion             0.0
# acid                  0.0
#                      ...
# zelectropoppoppost    0.0
# zgen                  0.0
# zindie                0.0
# zmodern               0.0
# zuliana               0.0
# Name: 0, Length: 5000, dtype: float64

# %%
combined.reset_index(inplace = True, drop = True)
temp = combined['trackName']
combined.drop(columns = ['genres', 'trackName'], inplace = True)

# %%
#Step 3
df = pd.concat([combined, genre_tfdf], axis = 1)
df.index = temp

# %%
combined.head()
# Out:
#                                            trackName  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 1                            Clancy Lowered the Boom
# 2                                          Gati Bali
# 3                                          Danny Boy
# 4                        When Irish Eyes Are Smiling
#
#                                               genres  artist_popularity  \
# 0  [classical, post-romantic era, russian romanti...           0.000293
# 1                                                 []           0.000366
# 2                                 [javanese gamelan]           0.000366
# 3                                                 []           0.000220
# 4                                                 []           0.000146
#
#       followers  danceability  energy       key  loudness  mode  speechiness  \
# 0  2.106536e-04         0.279   0.211  0.004447 -0.004352   1.0       0.0366
# 1  2.070743e-07         0.819   0.341  0.003113 -0.002694   1.0       0.4150
# 2  1.646072e-07         0.328   0.166  0.001334 -0.003216   1.0       0.0339
# 3  0.000000e+00         0.275   0.309  0.002223 -0.002017   1.0       0.0354
# 4  9.771203e-09         0.418   0.193  0.001334 -0.002186   1.0       0.0380
#
#    acousticness  instrumentalness  liveness  valence     tempo
# 0         0.982          0.878000     0.665   0.0594  0.001869
# 1         0.732          0.000000     0.160   0.9630  0.001407
# 2         0.961          0.913000     0.101   0.0394  0.002548
# 3         0.967          0.000028     0.381   0.1650  0.002311
# 4         0.957          0.000002     0.229   0.2530  0.002347

# %%
df.head()
# Out:
#                                                     artist_popularity  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...           0.000293
# Clancy Lowered the Boom                                      0.000366
# Gati Bali                                                    0.000366
# Danny Boy                                                    0.000220
# When Irish Eyes Are Smiling                                  0.000146
#
#                                                        followers  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...  2.106536e-04
# Clancy Lowered the Boom                             2.070743e-07
# Gati Bali                                           1.646072e-07
# Danny Boy                                           0.000000e+00
# When Irish Eyes Are Smiling                         9.771203e-09
#
#                                                     danceability  energy  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...         0.279   0.211
# Clancy Lowered the Boom                                    0.819   0.341
# Gati Bali                                                  0.328   0.166
# Danny Boy                                                  0.275   0.309
# When Irish Eyes Are Smiling                                0.418   0.193
#
#                                                          key  loudness  mode  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...  0.004447 -0.004352   1.0
# Clancy Lowered the Boom                             0.003113 -0.002694   1.0
# Gati Bali                                           0.001334 -0.003216   1.0
# Danny Boy                                           0.002223 -0.002017   1.0
# When Irish Eyes Are Smiling                         0.001334 -0.002186   1.0
#
#                                                     speechiness  acousticness  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...       0.0366         0.982
# Clancy Lowered the Boom                                  0.4150         0.732
# Gati Bali                                                0.0339         0.961
# Danny Boy                                                0.0354         0.967
# When Irish Eyes Are Smiling                              0.0380         0.957
#
#                                                     instrumentalness  ...  \
# trackName                                                             ...
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...          0.878000  ...
# Clancy Lowered the Boom                                     0.000000  ...
# Gati Bali                                                   0.913000  ...
# Danny Boy                                                   0.000028  ...
# When Irish Eyes Are Smiling                                 0.000002  ...
#
#                                                     (zdance,)  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...        0.0
# Clancy Lowered the Boom                                   0.0
# Gati Bali                                                 0.0
# Danny Boy                                                 0.0
# When Irish Eyes Are Smiling                               0.0
#
#                                                     (zelectropopgauze,)  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                  0.0
# Clancy Lowered the Boom                                             0.0
# Gati Bali                                                           0.0
# Danny Boy                                                           0.0
# When Irish Eyes Are Smiling                                         0.0
#
#                                                     (zelectropopindie,)  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                  0.0
# Clancy Lowered the Boom                                             0.0
# Gati Bali                                                           0.0
# Danny Boy                                                           0.0
# When Irish Eyes Are Smiling                                         0.0
#
#                                                     (zelectropopla,)  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...               0.0
# Clancy Lowered the Boom                                          0.0
# Gati Bali                                                        0.0
# Danny Boy                                                        0.0
# When Irish Eyes Are Smiling                                      0.0
#
#                                                     (zelectropoppop,)  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                0.0
# Clancy Lowered the Boom                                           0.0
# Gati Bali                                                         0.0
# Danny Boy                                                         0.0
# When Irish Eyes Are Smiling                                       0.0
#
#                                                     (zelectropoppoppost,)  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                    0.0
# Clancy Lowered the Boom                                               0.0
# Gati Bali                                                             0.0
# Danny Boy                                                             0.0
# When Irish Eyes Are Smiling                                           0.0
#
#                                                     (zgen,)  (zindie,)  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...      0.0        0.0
# Clancy Lowered the Boom                                 0.0        0.0
# Gati Bali                                               0.0        0.0
# Danny Boy                                               0.0        0.0
# When Irish Eyes Are Smiling                             0.0        0.0
#
#                                                     (zmodern,)  (zuliana,)
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...         0.0         0.0
# Clancy Lowered the Boom                                    0.0         0.0
# Gati Bali                                                  0.0         0.0
# Danny Boy                                                  0.0         0.0
# When Irish Eyes Are Smiling                                0.0         0.0
#
# [5 rows x 5013 columns]

# %% [markdown]
# #### Without Genres

# %%
combined.head()
# Out:
#                                            trackName  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 1                            Clancy Lowered the Boom
# 2                                          Gati Bali
# 3                                          Danny Boy
# 4                        When Irish Eyes Are Smiling
#
#                                               genres  artist_popularity  \
# 0  [classical, post-romantic era, russian romanti...           0.000293
# 1                                                 []           0.000366
# 2                                 [javanese gamelan]           0.000366
# 3                                                 []           0.000220
# 4                                                 []           0.000146
#
#       followers  danceability  energy       key  loudness  mode  speechiness  \
# 0  2.106536e-04         0.279   0.211  0.004447 -0.004352   1.0       0.0366
# 1  2.070743e-07         0.819   0.341  0.003113 -0.002694   1.0       0.4150
# 2  1.646072e-07         0.328   0.166  0.001334 -0.003216   1.0       0.0339
# 3  0.000000e+00         0.275   0.309  0.002223 -0.002017   1.0       0.0354
# 4  9.771203e-09         0.418   0.193  0.001334 -0.002186   1.0       0.0380
#
#    acousticness  instrumentalness  liveness  valence     tempo
# 0         0.982          0.878000     0.665   0.0594  0.001869
# 1         0.732          0.000000     0.160   0.9630  0.001407
# 2         0.961          0.913000     0.101   0.0394  0.002548
# 3         0.967          0.000028     0.381   0.1650  0.002311
# 4         0.957          0.000002     0.229   0.2530  0.002347

# %%
temp = combined
temp.index = combined['trackName']
temp.drop(columns = ['trackName', 'genres'], inplace =True)
temp.head()
# Out:
#                                                     artist_popularity  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                4.0
# Clancy Lowered the Boom                                           5.0
# Gati Bali                                                         5.0
# Danny Boy                                                         3.0
# When Irish Eyes Are Smiling                                       2.0
#
#                                                     followers  danceability  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...   560524.0         0.279
# Clancy Lowered the Boom                                 551.0         0.819
# Gati Bali                                               438.0         0.328
# Danny Boy                                                 0.0         0.275
# When Irish Eyes Are Smiling                              26.0         0.418
#
#                                                     energy   key  loudness  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...   0.211  10.0   -20.096
# Clancy Lowered the Boom                              0.341   7.0   -12.441
# Gati Bali                                            0.166   3.0   -14.850
# Danny Boy                                            0.309   5.0    -9.316
# When Irish Eyes Are Smiling                          0.193   3.0   -10.096
#
#                                                     mode  speechiness  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...   1.0       0.0366
# Clancy Lowered the Boom                              1.0       0.4150
# Gati Bali                                            1.0       0.0339
# Danny Boy                                            1.0       0.0354
# When Irish Eyes Are Smiling                          1.0       0.0380
#
#                                                     acousticness  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...         0.982
# Clancy Lowered the Boom                                    0.732
# Gati Bali                                                  0.961
# Danny Boy                                                  0.967
# When Irish Eyes Are Smiling                                0.957
#
#                                                     instrumentalness  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...          0.878000
# Clancy Lowered the Boom                                     0.000000
# Gati Bali                                                   0.913000
# Danny Boy                                                   0.000028
# When Irish Eyes Are Smiling                                 0.000002
#
#                                                     liveness  valence    tempo
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...     0.665   0.0594   80.954
# Clancy Lowered the Boom                                0.160   0.9630   60.936
# Gati Bali                                              0.101   0.0394  110.339
# Danny Boy                                              0.381   0.1650  100.109
# When Irish Eyes Are Smiling                            0.229   0.2530  101.665

# %% [markdown]
# ### Get Recommendations

# %%
similarity = cosine_similarity(temp[0:10_000])

# %%
sim = pd.DataFrame(similarity, index = temp[0:10_000].index, columns = temp[0:10_000].index)

# %%
sim.head()
# Out:
# trackName                                           Piano Concerto No. 3 in D Minor, Op. 30: III. Finale. Alla breve  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                                           1.000000
# Clancy Lowered the Boom                                                                      0.570540
# Gati Bali                                                                                    0.717702
# Danny Boy                                                                                    0.752065
# When Irish Eyes Are Smiling                                                                  0.728752
#
# trackName                                           Clancy Lowered the Boom  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                 0.570540
# Clancy Lowered the Boom                                            1.000000
# Gati Bali                                                          0.571433
# Danny Boy                                                          0.810696
# When Irish Eyes Are Smiling                                        0.864174
#
# trackName                                           Gati Bali  Danny Boy  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...   0.717702   0.752065
# Clancy Lowered the Boom                              0.571433   0.810696
# Gati Bali                                            1.000000   0.709496
# Danny Boy                                            0.709496   1.000000
# When Irish Eyes Are Smiling                          0.716964   0.985696
#
# trackName                                           When Irish Eyes Are Smiling  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                     0.728752
# Clancy Lowered the Boom                                                0.864174
# Gati Bali                                                              0.716964
# Danny Boy                                                              0.985696
# When Irish Eyes Are Smiling                                            1.000000
#
# trackName                                           Gati Mardika  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...      0.577175
# Clancy Lowered the Boom                                 0.727525
# Gati Bali                                               0.877794
# Danny Boy                                               0.739299
# When Irish Eyes Are Smiling                             0.764605
#
# trackName                                           The Wearing of the Green  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                  0.612009
# Clancy Lowered the Boom                                             0.766786
# Gati Bali                                                           0.593903
# Danny Boy                                                           0.809520
# When Irish Eyes Are Smiling                                         0.836732
#
# trackName                                           Morceaux de fantaisie, Op. 3: No. 2, Prélude in C-Sharp Minor. Lento  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                                           0.846847
# Clancy Lowered the Boom                                                                      0.411438
# Gati Bali                                                                                    0.511755
# Danny Boy                                                                                    0.515718
# When Irish Eyes Are Smiling                                                                  0.514139
#
# trackName                                           La Mañanita - Remasterizado  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                     0.399564
# Clancy Lowered the Boom                                                0.612019
# Gati Bali                                                              0.398055
# Danny Boy                                                              0.513346
# When Irish Eyes Are Smiling                                            0.553950
#
# trackName                                           Il Etait Syndiqué  ...  \
# trackName                                                              ...
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...           0.591482  ...
# Clancy Lowered the Boom                                      0.851258  ...
# Gati Bali                                                    0.549621  ...
# Danny Boy                                                    0.795755  ...
# When Irish Eyes Are Smiling                                  0.817638  ...
#
# trackName                                           Master Blaster (Jammin')  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                  0.156113
# Clancy Lowered the Boom                                             0.591055
# Gati Bali                                                           0.134602
# Danny Boy                                                           0.248416
# When Irish Eyes Are Smiling                                         0.302530
#
# trackName                                           Play for Today - 2006 Remaster  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                        0.151415
# Clancy Lowered the Boom                                                   0.548424
# Gati Bali                                                                 0.135675
# Danny Boy                                                                 0.257127
# When Irish Eyes Are Smiling                                               0.282239
#
# trackName                                           El Noa Noa  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...    0.465207
# Clancy Lowered the Boom                               0.750526
# Gati Bali                                             0.472830
# Danny Boy                                             0.581803
# When Irish Eyes Are Smiling                           0.608102
#
# trackName                                           Every Woman in the World  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                  0.483041
# Clancy Lowered the Boom                                             0.692820
# Gati Bali                                                           0.480163
# Danny Boy                                                           0.674042
# When Irish Eyes Are Smiling                                         0.691015
#
# trackName                                           Yeh, Yeh  Kill the Poor  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...  0.451963       0.458305
# Clancy Lowered the Boom                             0.774961       0.649779
# Gati Bali                                           0.455522       0.415414
# Danny Boy                                           0.652626       0.643336
# When Irish Eyes Are Smiling                         0.682636       0.615639
#
# trackName                                           Sometimes a Fantasy  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...             0.431955
# Clancy Lowered the Boom                                        0.751227
# Gati Bali                                                      0.368995
# Danny Boy                                                      0.598527
# When Irish Eyes Are Smiling                                    0.599819
#
# trackName                                           Don't Let Him Go  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...          0.428636
# Clancy Lowered the Boom                                     0.731085
# Gati Bali                                                   0.421003
# Danny Boy                                                   0.630935
# When Irish Eyes Are Smiling                                 0.634707
#
# trackName                                           Skateaway  \
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...   0.407876
# Clancy Lowered the Boom                              0.717001
# Gati Bali                                            0.409576
# Danny Boy                                            0.598999
# When Irish Eyes Are Smiling                          0.615980
#
# trackName                                           More Than I Can Say - Remastered
# trackName
# Piano Concerto No. 3 in D Minor, Op. 30: III. F...                          0.457912
# Clancy Lowered the Boom                                                     0.773072
# Gati Bali                                                                   0.429664
# Danny Boy                                                                   0.639084
# When Irish Eyes Are Smiling                                                 0.664341
#
# [5 rows x 10000 columns]

# %%
# combined.loc[['BREAK MY SOUL']]

# %%
# combined.loc[['BREAK MY SOUL']].index

# %%
similarity_bms = cosine_similarity(df[0:10_000])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 similarity_bms = cosine_similarity(df, df.loc[['Gati Bali']])
#
# File ~\anaconda3.1\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3.1\lib\site-packages\pandas\core\indexing.py:1191, in _LocIndexer._getitem_axis(self, key, axis)
#    1188     if hasattr(key, "ndim") and key.ndim > 1:
#    1189         raise ValueError("Cannot index with multidimensional key")
# -> 1191     return self._getitem_iterable(key, axis=axis)
#    1193 # nested tuple slicing
#    1194 if is_nested_tuple(key, labels):
#
# File ~\anaconda3.1\lib\site-packages\pandas\core\indexing.py:1133, in _LocIndexer._getitem_iterable(self, key, axis)
#    1131 # A collection of keys
#    1132 keyarr, indexer = self._get_listlike_indexer(key, axis)
# -> 1133 return self.obj._reindex_with_indexers(
#    1134     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1135 )
#
# File ~\anaconda3.1\lib\site-packages\pandas\core\generic.py:5032, in NDFrame._reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    5029     indexer = ensure_platform_int(indexer)
#    5031 # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5032 new_data = new_data.reindex_indexer(
#    5033     index,
#    5034     indexer,
#    5035     axis=baxis,
#    5036     fill_value=fill_value,
#    5037     allow_dups=allow_dups,
#    5038     copy=copy,
#    5039 )
#    5040 # If we've made a copy once, no need to make another one
#    5041 copy = False
#
# File ~\anaconda3.1\lib\site-packages\pandas\core\internals\managers.py:675, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     672     return result
#     674 if consolidate:
# --> 675     self._consolidate_inplace()
#     677 # some axes don't allow reindexing with dups
#     678 if not allow_dups:
#
# File ~\anaconda3.1\lib\site-packages\pandas\core\internals\managers.py:1685, in BlockManager._consolidate_inplace(self)
#    1683 def _consolidate_inplace(self) -> None:
#    1684     if not self.is_consolidated():
# -> 1685         self.blocks = tuple(_consolidate(self.blocks))
#    1686         self._is_consolidated = True
#    1687         self._known_consolidated = True
#
# File ~\anaconda3.1\lib\site-packages\pandas\core\internals\managers.py:2084, in _consolidate(blocks)
#    2082 new_blocks: list[Block] = []
#    2083 for (_can_consolidate, dtype), group_blocks in grouper:
# -> 2084     merged_blocks = _merge_blocks(
#    2085         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2086     )
#    2087     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2088 return new_blocks
#
# File ~\anaconda3.1\lib\site-packages\pandas\core\internals\managers.py:2111, in _merge_blocks(blocks, dtype, can_consolidate)
#    2104 new_values: ArrayLike
#    2106 if isinstance(blocks[0].dtype, np.dtype):
#    2107     # error: List comprehension has incompatible type List[Union[ndarray,
#    2108     # ExtensionArray]]; expected List[Union[complex, generic,
#    2109     # Sequence[Union[int, float, complex, str, bytes, generic]],
#    2110     # Sequence[Sequence[Any]], SupportsArray]]
# -> 2111     new_values = np.vstack([b.values for b in blocks])  # type: ignore[misc]
#    2112 else:
#    2113     bvals = [blk.values for blk in blocks]
#
# File <__array_function__ internals>:5, in vstack(*args, **kwargs)
#
# File ~\anaconda3.1\lib\site-packages\numpy\core\shape_base.py:282, in vstack(tup)
#     280 if not isinstance(arrs, list):
#     281     arrs = [arrs]
# --> 282 return _nx.concatenate(arrs, 0)
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# MemoryError: Unable to allocate 4.79 GiB for an array with shape (5013, 128295) and data type float64

# %%
# sim.sort_values(by = 'BREAK MY SOUL', ascending = False)

# %%
def get_reccomendation(song):
    similarity = cosine_similarity(df, df.loc[[f'{song}']])
